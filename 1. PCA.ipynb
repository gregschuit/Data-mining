# %% [markdown]
# # Principal Component Analisis

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# First, we generate some random normalized gaussian data.

# %%
mean = [2, 3, 5]

# %%
precov = [[2, 3, 0],
          [1, 2, 1],
          [1, 1, 2]]

# %%
cov = np.dot(precov, np.transpose(precov))

# %%
x, y, z = np.random.multivariate_normal(mean, cov, 150).T
x = np.array([(d - min(x)) / (max(x) - min(x)) for d in x])
y = np.array([(d - min(y)) / (max(y) - min(y)) for d in y])
z = np.array([(d - min(z)) / (max(z) - min(z)) for d in z])

plt.figure(figsize=(5, 5))
plt.scatter(x, y)
plt.show()

# %% [markdown]
# Now, we get the empirical covariance and the eigen vectors.

# %%
data_matrix = np.vstack([x,y,z])
empiric_covariance = np.cov(matriz_datos)

# %%
eig_val, eig_vec = np.linalg.eig(empiric_covariance)
eig_val, eig_vec
# Out:
# (array([0.0892922 , 0.01698829, 0.00066597]),
#  array([[-0.52893038, -0.64074551,  0.55648706],
#         [-0.67758429, -0.07597566, -0.73151024],
#         [-0.51099137,  0.76398488,  0.39397325]]))

# %%
plt.figure(figsize=(5, 5))

plt.scatter(x, y)
scale = 0.4

plt.arrow(x.mean(), y.mean(), scale * eig_vec[0][0], scale * eig_vec[0][1], color='red', head_width=0.02)
plt.arrow(x.mean(), y.mean(), scale * eig_vec[2][0], scale * eig_vec[2][1], color='red', head_width=0.02)
plt.show()

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)


soa = np.array([[0, 0, 1, 1, -2, 0],
                [0, 0, 2, 1, 1, 0],
                [0, 0, 3, 2, 1, 0]])

X, Y, Z = (x.mean()*np.ones(3), y.mean()*np.ones(3), z.mean()*np.ones(3))
dX, dY, dZ = eig_vec


ax.quiver(X, Y, Z, dX, dY, dZ, color='red')



plt.show()
